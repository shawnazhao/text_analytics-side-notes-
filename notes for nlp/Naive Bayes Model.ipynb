# %% [markdown]
# # Naive Bayes Classifiers
# ### prior probability:
# ### posterior probability
# ![image.png](attachment:image.png)
#
# X is the word y is the class the word belongs to
#
# so finding the right class y*of the word

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# Naive Assumption: given the class label, features themselves are assumed to be independent of each other

# %%
# it is called naive because there are phrases, words aint exactly independent of each other

# %% [markdown]
# # with a group of features" with a group of words in a sentence
#
# ![image.png](attachment:image.png)
#
# smoothing when a feature x done have any occurance
# - additive smoothing: just add a dummy count

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## two classes of the bayes model
# 1. multinomial bayes model
#     - a normal distribution like the word occurrences and the tf-idf
# 2. bernoule bayes model
#     - binary whether a word occurs or not
